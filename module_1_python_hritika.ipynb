# %% [markdown]
# **1. Write a python program to sum of the first n positive integers**

# %%
n = int(input('Enter the number: '))
r = sum(range(n+1))
print("The sum of the first",n,"positive integers is:-",r)
# Out:
# Enter the number: 4
# The sum of the first 4 positive integers is:- 10

# %% [markdown]
# **2. Write a Python program to count occurrences of a substring in a string.**

# %%
print('Enter the string:')
n = input()
n = n.lower()
print('Enter the substring:')
n1 = input()
n1 = n1.lower()
r = n.count(n1)
print('Substring',n1,'has occurred',r,'time(s)')
# Out:
# Enter the string:
# The red sea and the black sea
# Enter the substring:
# the
# Substring the has occurred 2 time(s)

# %% [markdown]
# **3. Write a Python program to count the occurrences of each word in a given sentence.**

# %%
def word_occ(str):
  str = str.lower()
  count = dict()
  words = str.split(' ')
  for word in words:
    if word in count:
      count[word] += 1
    else:
      count[word] = 1

  for key, value in count.items():
    print(key, 'has occured', value, 'time(s)')

# %%
word_occ('The Pacific ocean is larger than any other oceans in the world')
# Out:
# the has occured 2 time(s)
# pacific has occured 1 time(s)
# ocean has occured 1 time(s)
# is has occured 1 time(s)
# larger has occured 1 time(s)
# than has occured 1 time(s)
# any has occured 1 time(s)
# other has occured 1 time(s)
# oceans has occured 1 time(s)
# in has occured 1 time(s)
# world has occured 1 time(s)

# %% [markdown]
# **4. Write a Python program to get a single string from two given strings, separated by a space and swap the first
# two characters of each string**

# %%
def swap(x,y):
  new_x = y[:2] + x[2:]
  new_y = x[:2] + y[2:]
  return new_x + ' ' + new_y

# %%
swap('cat','dog')
# Out:
# 'dot cag'

# %% [markdown]
# **5. Write a Python program to add 'ing' at the end of a given string (length should be at least 3).
# If the given string already ends with 'ing' then add 'ly' instead If the string length of the given
# string is less than 3, leave it unchanged**

# %%
def string(str):
  length = len(str)
  if length > 2:
    if str[-3:] == 'ing':
      str += 'ly'
    else:
      str += 'ing'
  return str

# %%
string('xyz')
# Out:
# 'xyzing'

# %%
string('playing')
# Out:
# 'playingly'

# %% [markdown]
#  **6. Write a Python program to find the first appearance of the substring 'not' and 'poor' from a given string, if
# 'not' follows the 'poor', replace the whole 'not'...'poor' substring with 'good'.
# Return the resulting string**

# %%
a = input('Enter the string:- ')
b=c=0
b = a.find('not')
c = a.find('poor')
if (b >= 0 or c >=0):
  d = a.replace(a[b:c+4], 'good')
print(d)
# Out:
# Enter the string:- He is not poor at swimming
# He is good at swimming

# %% [markdown]
# **7. Program to find Greatest Common Divisor of two numbers.
# For example, the GCD of 20 and 28 is 4 and GCD of 98 and 56 is 14**

# %%
import math

# %%
x = int(input('Enter the first number: '))
y = int(input('Enter the second number: '))

r = math.gcd(x,y)
print('The GCD of',x,'and',y,'is',r)
# Out:
# Enter the first number: 55
# Enter the second number: 44
# The GCD of 55 and 44 is 11

# %% [markdown]
# **8. Write a Python program to check whether a list contains a sublist.**

# %%
l = list(input('Enter a list: '))
sub_l = list(input('Enter sublist: '))
 
i = 0
if(set(sub_l).issubset(set(l))):
    i += 1
 
if (i):
    print("Yes, the list contains the given sublist.")
else:
    print("No, the list does not contain the given sublist.")
# Out:
# Enter a list: 1,2,3,4
# Enter sublist: 5,7
# No, the list does not contain the given sublist.

# %% [markdown]
# **9. Write a Python program to find the second smallest number in a list.**

# %%
def s(l):
    length = len(l)
    l.sort()
    print("Second Smallest element is:", l[1])

# %%
l = [10, 20, 30, 40, 50]

# %%
s(l)
# Out:
# Second Smallest element is: 20

# %% [markdown]
# **10. Write a Python program to get unique values from a list.**

# %%
l = [10,20,20,30,10,50,60,50,40]
print("Original List :",l)
l2 = set(l)
l3 = list(l2)
print("List of unique values :",l3)
# Out:
# Original List : [10, 20, 20, 30, 10, 50, 60, 50, 40]
# List of unique values : [40, 10, 50, 20, 60, 30]

# %% [markdown]
# **11. Write a Python program to unzip a list of tuples into individual lists.**

# %%
t = [('a','b'), (3,4), ('d','f')]
print(list(zip(*t)))
# Out:
# [('a', 3, 'd'), ('b', 4, 'f')]

# %% [markdown]
# **12. Write a Python program to convert a list of tuples into a dictionary**

# %%
t = [('Nirali',10),('Mudra',20),('Zeel',30),('Monika',40)]
d = dict(t)
print(d)
# Out:
# {'Nirali': 10, 'Mudra': 20, 'Zeel': 30, 'Monika': 40}

# %% [markdown]
# **13. Write a Python program to sort a dictionary (ascending /descending) by value.**

# %%
import operator

d = {1: 'a', 2: 'd', 3: 'c', 4: 'b', 5: 'e'}
s= dict(sorted(d.items(), key=operator.itemgetter(1)))
print('ascending order :',s)
s1= dict(sorted(d.items(), key=operator.itemgetter(1),reverse=True))
print('descending order :',s1)
# Out:
# ascending order : {1: 'a', 4: 'b', 3: 'c', 2: 'd', 5: 'e'}
# descending order : {5: 'e', 2: 'd', 3: 'c', 4: 'b', 1: 'a'}

# %% [markdown]
# **14. Write a Python program to find the highest 3 values in a dictionary.**

# %%
import operator

d = {"A":1,"B":4,"C":3,"D":5,"E":2}

r = dict(sorted(d.items(),key=operator.itemgetter(1),reverse=True)[:3])
print(r)
# Out:
# {'D': 5, 'B': 4, 'C': 3}

# %% [markdown]
# **15. Given a number n, write a python program to make and print the list of Fibonacci series up to n.
# Input : n=7
# Hint : first 7 numbers in the series
# Expected output :
# First few Fibonacci numbers are 0, 1, 1, 2, 3, 5, 8, 13**

# %%
def fib_num(n):
  n1 = 0
  n2 = 1
  if n < 1:
    return

  print(n1, end = ', ')
  for i in range(1,n):
    print(n2, end = ', ')
    n3 = n1 + n2
    n1 = n2
    n2 = n3

# %%
fib_num(7)
# Out:
# 0, 1, 1, 2, 3, 5, 8,

# %% [markdown]
# **16. Counting the frequencies in a list using a dictionary in Python.
# Input : [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]
# Expected output : 1 : 5 , 2 : 4 , 3 : 3 , 4 : 3 , 5 : 2**

# %%
def CountFreq(l):
  freq = {}
  li = l.sort()
  for items in l:
    freq[items] = l.count(items)
  print(freq)

# %%
l =[1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]

# %%
CountFreq(l)
# Out:
# {1: 5, 2: 4, 3: 3, 4: 3, 5: 2}

# %% [markdown]
# **17. Write a python program using function to find the sum of odd series and even series
# Odd series: 12/ 1! + 32/ 3! + 52/ 5!+……n
# Even series: 22/ 2! + 42/ 4! + 62/ 6!+……n**

# %%
import math

series = [345, 893, 1948, 34, 2346]
odd_sum = 0
even_sum = 0
for s in series:
  odd_sum += sum(if int(s) in s%2==1):
   print('The sum of odd series is:-',odd_sum)

  even_sum += sum(if int(s) in s%2==0):
   print('The sum of even series is:-',even_sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-f6185bc3ce64> in <module>()
#       5 even_sum = 0
#       6 for s in series:
# ----> 7   odd_sum += sum(int(s)%2==1)
#       8   even_sum += sum(int(s)%2==0)
#       9 print('The sum of even series is:-',even_sum)
#
# TypeError: 'bool' object is not iterable

# %% [markdown]
# **18. Python Program to Find Factorial of Number Using Recursion**

# %%
 def factorial(n):
    if (n==1 or n==0):
      return 1  
    else:
      return (n * factorial(n-1))

# %%
factorial(5)
# Out:
# 120

# %% [markdown]
# **19. Write a Python function that takes a list and returns a new list with unique elements of the first list.**

# %%
def newlist(l):
    a = set(l)
    print(sorted(a))

# %%
newlist([1,2,3,4,5,2,3,2,1])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **20. Mini project :
# Problem Statement : Password Generator
# Make a program to generate a strong password using the input given by the user. To generate a password,
# randomly take some words from the user input and then include numbers, special characters and capital
# letters to generate the password. Also, keep a check that password length is more than 8 characters.
# Note: Include Exception handling wherever required. Also, make a ‘User’ class and store the details like user
# id, name and password of each user as a tuple.**

# %%
def n(pw):
  pw = int(input('Enter the number(s) for password length: '))
  import string
  import random
  s1 = string.ascii_lowercase
  s2 = string.ascii_uppercase
  s3 = string.digits
  s4 = string.punctuation 
  if pw >= 8:
              s = []
              s.extend(list(s1))
              s.extend(list(s2))
              s.extend(list(s3))
              s.extend(list(s4))
              random.shuffle(s)
              print('Your password is:-', ''.join(s[0:pw])) 
  else:
            raise Exception ('Wrong input!')


class User:
  def user(self):
    print('Welcome to Password Generator!')
class User1(User):
    def details(self):
      User.user(self)
      user_id = (1,234)
      print('User_id :-\n',user_id)
      print(type(user_id)) 
      name = tuple("Nirali")
      print('Name:-\n',name)
      print(type(name))
      print('Password:-')
      password = n(7)
      password = ()
      print(type(password))

class User2(User):
    def details(self):
      User.user(self)
      user_id = (1,235)
      print('User_id :-\n',user_id)  
      name = tuple('Mudra')
      print('Name:-\n',name)
      print('Password:-')
      password = n(8)
      password = ()

class User3(User):
    def details(self):
      User.user(self)
      user_id = (1,237)
      print('User_id :-\n',user_id)  
      name = tuple('Romit')
      print('Name:-\n',name)
      print('Password:-')
      password = n(12)   
      password = ()

# %%
obj = User1()
obj.details()
# Out:
# Welcome to Password Generator!
# User_id :-
#  (1, 234)
# <class 'tuple'>
# Name:-
#  ('N', 'i', 'r', 'a', 'l', 'i')
# <class 'tuple'>
# Password:-
# Enter the number(s) for password length: 9
# Your password is:- ~FhJZU^`f
# <class 'tuple'>
